# %% [markdown]
# <a href="https://colab.research.google.com/github/vinyl-bin/selenium/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4, 5, 6], [92.46, 92.51, 92.57, 92.31, 92.37, 92.23])
plt.xlabel('LSTM layer')
plt.ylabel('test accuracy(%)')

plt.savefig('/home/LSTMy1.png')
